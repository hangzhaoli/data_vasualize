# %%
#2022年2月20日阿朝项目  python 可视化

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np 
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional  
plt.plot(x,y,'r-')
plt.xlabel('x Label')
plt.ylabel('Y Label')
plt.title('Hanz')
plt.show()#如果不在juypter notebook上 可以用， 不在不用也可以

# %%
plt.subplot(1,2,1) # 1行，2列，1plot form 
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# 00
fig = plt.figure() #对象 

axes = fig.add_axes([0.1,0.1,0.8,0.8]) #([在内部添加一个数组，比例，0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])  #20%from the left, 50% up from the buttom 40% canvas size weights, 30% canva size of height

# %%
#把上面这个框框移动到右下角如何呢？

fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.1,0.4,0.3])

axes1.plot(x,y)

axes2.plot(y,x)

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Larger Plot')

axes2.plot(x,y)
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig,axes = plt.subplots(nrows=1,ncols = 2)

#axes.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(x,y)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# # Figure Size and DPI

# %%
fig,axes = plt. subplots(2,1,figsize = (8,3))

axes[0].plot(x,y,'green')
axes[1].plot(y,x)
plt.tight_layout()
#ax = fig.add_axes([0,0,1,1])

# %%
fig.savefig('my_picture.png')  #可以把这种图像存储下来

# %%
fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubed')
ax.set_title('Title')


ax.legend(loc = 1) #把标识放入的位置

# %%
#Plot Apperance 

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,y, color='#FF8C00')   #RGB HEX code
ax.plot(x,y, color='purple',linewidth =3,alpha = 0.5) #linewidth 是把线调宽 #alpha 是线的透明度
ax.plot(x,y, color='purple',lw =3,alpha = 0.5)  #线的宽度替换为lw 也可以

# %%
fig= plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,y, color='#FF8C00')   #RGB HEX code

ax.plot(x,y, color='purple',lw =3,linestyle='-.')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
fig= plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,y, color='#FF8C00')   #RGB HEX code

ax.plot(x,y, color='purple',lw =3,linestyle='--',marker='+',markersize=20,markerfacecolor='yellow',markeredgewidth=3) #linestyle 可以替换为ls

# %%
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.plot(x,y)
plt.title('Title')
# Out:
# /Users/hangzhaoli/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2]) 

#fig = plt.figure()

ax1.plot(x,y)
ax2.plot(y,x)

#axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
#axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4]) 


ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

ax2.plot(x,y)
ax2.set_xlim([20,22])#给出20 到22 的范围
ax2.set_ylim([30,50])
# Out:
# (30, 50)

# %%
fig, axes = plt.subplots(1,2)
axes[0].plot(x,y,color = 'red',lw =3, ls='--')
axes[1].plot(x,z,color = 'blue',lw =2, ls = '-')

# %% [markdown]
# # about seaborn

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde = False, bins=30)  #bins 给出多少不同的分支

# %%
sns.jointplot(x='total_bill',y='tip',data=tips) #kind参数，可以让点图换成其他形式

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind = 'hex') #kind参数，可以让点图换成其他形式

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind = 'reg') #kind参数，可以让点图换成其他形式

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind = 'kde')

# %%
sns.pairplot(tips) #图形的组合 每个元素与不同的列生成的整体的关联

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# # Categorical Plots

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator =np.std )

# %%
sns.countplot(x =  'sex',data =tips)

# %%
sns.boxplot(x='day',y= 'total_bill',data= tips)  #y的维度是数量，

# %%
sns.boxplot(x='day',y= 'total_bill',data= tips,hue = 'smoker')  #不仅能看到这个人day by day totalbill，还能看到他
#是否是smoker

# %%
sns.violinplot(x='day',y='total_bill', data=tips)

# %%
sns.violinplot(x='day',y='total_bill', data=tips,hue='sex',split= True)

# %%
sns.stripplot(x='day', y ='total_bill',data = tips)#x 是category 维度，y 是Num 维度

# %%
sns.stripplot(x='day', y ='total_bill',data = tips,jitter= True)#jitter在这里添加了一些混乱的信息让密度更为准确一些

# %%
sns.violinplot(x='day', y ='total_bill',data = tips,jitter= True)
sns.swarmplot(x='day',y='total_bill',data= tips,color = 'black')    #不好看但是用以清晰看数据分布

# %%
sns.factorplot(x='day',y='total_bill', data= tips,kind='violin')
# Out:
# /Users/hangzhaoli/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot= True)

# %%
sns.heatmap(tc,annot= True,cmap='coolwarm')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')   #先map一个plot类型 distplot，然后把结果根据 col 和row进行区分

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue = 'sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue = 'sex',markers= ['o','v']) #为其赋予不同的符号

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue = 'sex',markers= ['o','v'], scatter_kws={'s':100})
#scatter改变Marker的
#大小

# %%
sns.lmplot(x= 'total_bill',y = 'tip',data = tips, col = 'sex')#hue 改成了col 以后，分类变成了两栏，按照列的sex两个类别分类

# %%
sns.lmplot(x= 'total_bill',y = 'tip',data = tips, col = 'sex',row = 'time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect = 0.6,size = 5)
# Out:
# /Users/hangzhaoli/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Style and color

# %%
#Style and color

#sns.set_style('ticks')
#sns.countplot(x='sex',data = tips)
#sns.despine(left=True,bottom = True)

# %%
#plt.figure(figsize=(12,3))
#sns.countplot(x='sex',data=tips)

# %%
#sns.set_context('poster',font_scale='3')
#sns.countplot(x='sex',data=tips)

# %%
#练习；
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x = 'fare',y='age', data = titanic)

# %%
sns.distplot(titanic['fare'],kde =False,color = 'red',bins = 30)#kde 在这里表示折线图是否采用高斯分布

# %%
sns.boxplot(x='class',y='age',data=titanic, palette= 'rainbow')

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette= 'rainbow')

# %%
sns.countplot(x='sex',data=titanic)

# %%
tc = titanic.corr()

# %%
sns.heatmap(tc,annot= True)
plt.title('titanic.corr')
# Out:
# Text(0.5, 1.0, 'titanic.corr')

# %%
#sns.lmplot(x= 'total_bill',y = 'tip',data = tips, col = 'sex')
g= sns.FacetGrid(data=titanic,col = 'sex')
g.map(plt.hist,'age')

# %%
sns.distplot(titanic['fare'],kde =False,color = 'red')

# %%
flights.head()

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118e3fc50>,
# ...
#       dtype=object)

# %%
plt.show()
